# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="../env/.env")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
from pydantic import BaseModel
from langchain.agents import create_agent

class Answer(BaseModel):
    summary: str
    confidence: float

agent = create_agent(model="openai:gpt-5.5", tools=[], response_format=Answer)
result = agent.invoke({"messages": [{"role": "user", "content": "Summarize AI trends"}]})
result["structured_response"]
# Out:
# Answer(summary='Key AI trends include the rapid adoption of generative AI across business workflows, especially for writing, coding, customer support, marketing, and data analysis. Multimodal models that handle text, images, audio, and video are becoming more capable and widely used. AI agents are emerging as tools that can plan, use software, and complete multi-step tasks with less human input. Enterprises are focusing more on private, secure, and domain-specific AI, often using smaller or fine-tuned models to reduce cost and improve reliability. Regulation, copyright, data privacy, and AI safety remain major concerns, pushing organizations toward governance frameworks and responsible AI practices. Hardware demand, especially for GPUs and AI accelerators, continues to shape the market. At the same time, open-source models are improving quickly, increasing competition and giving companies more deployment options.', confidence=0.86)
